# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Seaborn внутри себя просто вызывает методы matplotlib

# %%
df = pd.read_csv ('../course_data/05-Seaborn/dm_office_sales.csv')

# %%
df.head()
# Out:
#           division  level of education  training level  work experience  \
# 0         printers        some college               2                6
# 1         printers  associate's degree               2               10
# 2      peripherals         high school               0                9
# 3  office supplies  associate's degree               2                5
# 4  office supplies         high school               1                5
#
#    salary   sales
# 0   91684  372302
# 1  119679  495660
# 2   82045  320453
# 3   92949  377148
# 4   71280  312802

# %%
plt.figure(figsize=(12,4))

sns.scatterplot(x='salary', y='sales', data=df, hue='level of education');
# plt.show(sns.scatterplot(x='salary', y='sales', data=df))

# %%
plt.figure(figsize=(12,4))

sns.scatterplot(x='salary', y='sales', data=df, hue='salary');
# plt.show(sns.scatterplot(x='salary', y='sales', data=df))

# %%
plt.figure(figsize=(12,4), dpi=200)

sns.scatterplot(x='salary', y='sales', data=df, hue='level of education', palette='Dark2');
# plt.show(sns.scatterplot(x='salary', y='sales', data=df))
plt.savefig('graph_level_of_education.png')

# %%
plt.figure(figsize=(12,4))
sns.scatterplot(x='salary', y='sales', data=df, size='work experience');

# %%
plt.figure(figsize=(12,4), dpi=200)
sns.scatterplot(x='salary', y='sales', data=df, s=175, style='level of education', hue='level of education', alpha=0.8);

# %%
plt.figure(figsize=(12,4), dpi=200)
sns.scatterplot(x='salary', y='sales', data=df, s=200, alpha=0.2);
