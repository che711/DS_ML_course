# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[11], line 2
#       1 import numpy as np
# ----> 2 import pandas as pd
#       3 import matplotlib.pyplot as plt
#       4 import seaborn as sns
#
# ModuleNotFoundError: No module named 'pandas'

# %%
df = pd.read_csv('../course_data/08-Linear-Regression-Models/Advertising.csv')
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 df = pd.read_csv('../course_data/08-Linear-Regression-Models/Advertising.csv')
#       2 df.head()
#
# NameError: name 'pd' is not defined

# %%
# разбиваем данные на признаки и целевую переменную
X = df.drop('sales',axis=1)
y = df['sales']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 2
#       1 # разбиваем данные на признаки и целевую переменную
# ----> 2 X = df.drop('sales',axis=1)
#       3 y = df['sales']
#
# NameError: name 'df' is not defined

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
polynomial_converter = PolynomialFeatures(degree=3, include_bias=False)

# %%
poly_features = polynomial_converter.fit_transform(X)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 poly_features = polynomial_converter.fit_transform(X)
#
# NameError: name 'X' is not defined
