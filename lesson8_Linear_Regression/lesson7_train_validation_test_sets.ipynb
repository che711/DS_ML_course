# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('../course_data/DATA/Advertising.csv')
df.head()
# Out:
#       TV  radio  newspaper  sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %% [markdown]
# ### Разбиваем данные на обучающий и тестовый наборы данных -Train | Test Split
# 0. Очищаем данные Х и y (при необходимости)
# 1. Разбиваем данные на обечающий, оценочный и тестовый наборы данных - как для Х так и для y
# 2. Обучаем объект Scaler на обучающих данных Х
# 3. Применяем масштабирование (scale) для тестовых данных Х
# 4. Создаем модель
# 5. Обучаем модель на обучающих данных Х
# 6. Оцениваем модель на тестовых данных Х(создавая предсказания и сравнивая их Y_eval)
# 7. Уточняем параметры модели, повторяя шаги 5 и 6
# 8. Вычисляем финальные метрики на тестовом наборе данных(после этого уже нельзя возвращаться и делать уточнения!)

# %%
X = df.drop('sales', axis=1)

# %%
y = df['sales']
