# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
with open('../course_data/DATA/Ames_Housing_Feature_Description.txt', 'r'):
# Out:
#   Cell In[6], line 1
#     with open('../course_data/DATA/Ames_Housing_Feature_Description.txt'):
#                                                                           ^
# SyntaxError: incomplete input

# %%
pwd
# Out:
# '/home/andrew/Python projects/DS_ML_course/lesson8_Linear_Regression'
