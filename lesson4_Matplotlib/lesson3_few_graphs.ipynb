# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
a = np.linspace(0,10,11)
b = a**4

# %%
x = np.arange(0,10)
y = 2*x

# %%
fig,axes = plt.subplots(nrows=1, ncols=2, )

axes[0].plot(x,y)
axes[1].plot(a,b*2)

# %%
type(axes)
# Out:
# numpy.ndarray

# %%
axes.shape
# Out:
# (2,)

# %%
#fig,axes = plt.subplots(nrows=2, ncols=2, figsize=(4,10), dpi=200)
fig,axes = plt.subplots(nrows=2, ncols=2)

axes[0][0].plot(x,y)
axes[1][0].set_ylabel('Y label')
axes[1][0].set_xlabel('X label')
axes[1][0].set_title("Test graph")
axes[1][1].plot(a,b);

fig.suptitle("Figure Level Title")

fig.subplots_adjust(wspace=0.5, hspace=0.5)
plt.tight_layout()

fig.set_figwidth(10)
fig.savefig('few_graphs.png',bbox_inches='tight')

# %%
fig,axes = plt.subplots(nrows=3, ncols=1, )

axes[0].plot(x,y)
axes[1].plot(a,b)
axes[2].plot(a,b**0.1)

plt.tight_layout()
fig.subplots_adjust(hspace=0.9)
